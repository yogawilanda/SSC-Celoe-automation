# %%
import openpyxl

# Load the Excel file
workbook = openpyxl.load_workbook(filename="aset/asetEdomGjl2223.xlsx")
worksheet = workbook["Informatika"]

# Find the first empty column (iteratively)
next_empty_column = 1
while worksheet.cell(row=1, column=next_empty_column).value is not None:
    next_empty_column += 1
    print(f"Column {openpyxl.utils.get_column_letter(next_empty_column - 1)} is not empty.")

print(f"The first empty column is {openpyxl.utils.get_column_letter(next_empty_column)}.")

# Set the input here to let user decide if yes then proceed, no the exit the program
set_title_confirmation = input("Press Enter to continue...")

setTitle = worksheet.cell(row=1, column=next_empty_column).value = "HEHEHEH"
print("Title inserted in column {next_empty_column}.")
if  input == "yes":
    setTitle
    pass

# Insert the title in the first empty row of the empty column



# # Insert data in the next row of the same column
# worksheet.cell(row=2, column=next_empty_column).value = "Your data here"  # Replace with actual data

# # Save the modified Excel file
# workbook.save(filename="aset/asetEdomGjl2223.xlsx")
# Out:
# Column A is not empty.
# Column B is not empty.
# Column C is not empty.
# Column D is not empty.
# Column E is not empty.
# Column F is not empty.
# Column G is not empty.
# Column H is not empty.
# Column I is not empty.
# The first empty column is J.
# Title inserted in column {next_empty_column}.

# %%
import openpyxl

# Load the Excel file
workbook = openpyxl.load_workbook(filename="aset/asetEdomGjl2223.xlsx")
worksheet = workbook["Informatika"]

# Find the first empty column (iteratively)
next_empty_column = 1
while worksheet.cell(row=1, column=next_empty_column).value is not None:
    next_empty_column += 1
    print(f"Column {openpyxl.utils.get_column_letter(next_empty_column - 1)} is not empty.")

print(f"The first empty column is {openpyxl.utils.get_column_letter(next_empty_column)}.")

# Prompt for user confirmation
set_title_confirmation = input("Press Enter to continue, or type 'no' to exit: ")

if set_title_confirmation.lower() != "no":  # Case-insensitive check for "no"
    # Insert the title in the first row of the empty column
    worksheet.cell(row=1, column=next_empty_column).value = "HEHEHEH"
    print(f"Title inserted in column {openpyxl.utils.get_column_letter(next_empty_column)}.")

    # Insert data in the next row of the same column (uncomment if needed)
    # worksheet.cell(row=2, column=next_empty_column).value = "Your data here"

    # Save the modified Excel file
    workbook.save(filename="aset/asetEdomGjl2223.xlsx")
else:
    print("Exiting program.")
# Out:
# Column A is not empty.
# Column B is not empty.
# Column C is not empty.
# Column D is not empty.
# Column E is not empty.
# Column F is not empty.
# Column G is not empty.
# Column H is not empty.
# Column I is not empty.
# Column J is not empty.
# The first empty column is K.
# Title inserted in column K.

# %%
import openpyxl

def find_empty_column(worksheet):
    next_empty_column = 1
    while worksheet.cell(row=1, column=next_empty_column).value is not None:
        next_empty_column += 1
        print(f"Column {openpyxl.utils.get_column_letter(next_empty_column - 1)} is not empty.")
    return next_empty_column

def insert_title(worksheet, column, title):
    worksheet.cell(row=1, column=column).value = title
    print(f"Title inserted in column {openpyxl.utils.get_column_letter(column)}.")

def main():
    try:
        workbook = openpyxl.load_workbook(filename="aset/asetEdomGjl2223.xlsx")
        worksheet = workbook["Informatika"]
        
        print(f"Filenya ketemu nih!\nNama sheet: {worksheet}.")
    
    except FileNotFoundError:
        print("File not found. Please check the file path.")
        return
    except KeyError:
        print("Worksheet not found. Please check the worksheet name.")
        return

    next_empty_column = find_empty_column(worksheet)

    # Prompt for user confirmation
    set_title_confirmation = input("Press Enter to continue, or type 'no' to exit: ").lower().strip()

    if set_title_confirmation == "yes":
        # Insert the title in the first row of the empty column
        insert_title(worksheet, next_empty_column, "PRODI")

    # Insert data in the next rows of the same column, starting from the second row
    for i in range(2, worksheet.max_row + 1):  # Iterate over all rows in the worksheet
        previous_row_data = worksheet.cell(row=i - 1, column=next_empty_column).value
        if previous_row_data is not None:
            worksheet.cell(row=i, column=next_empty_column).value = worksheet.title
            print(f"Data inserted in column {openpyxl.utils.get_column_letter(next_empty_column)}.")
        else:
            break  # Break the loop if the previous row is empty

        # Save the modified Excel file
        workbook.save(filename="aset/asetEdomGjl2223.xlsx")

    else:
        print("Exiting program.")

if __name__ == "__main__":
    main()
# Out:
# Filenya ketemu nih!
# Nama sheet: <Worksheet "Informatika">.
# Column A is not empty.
# Column B is not empty.
# Column C is not empty.
# Column D is not empty.
# Column E is not empty.
# Column F is not empty.
# Column G is not empty.
# Column H is not empty.
# Title inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Data inserted in column I.
# Exiting program.
